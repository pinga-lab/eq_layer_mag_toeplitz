# %% [markdown]
# # Import

# %%
import numpy as np
from scipy.interpolate import griddata
from scipy import interpolate, signal
import pickle as pickle

# %% [markdown]
# # Observed Grid and Data

# %%
# Total field anomaly of aero survey at z=900m in Carajas, Para, Brasil
yi_c,xi_c,zi_c,dobs_c = np.genfromtxt('1123_MagLine.XYZ', skip_header=11, usecols = (0, 1, 7, 15),
                                              invalid_raise=False, unpack=True)

# Total field anomaly of aero survey Tie lines at z=900m in Carajas, Para, Brasil
#yi_f2,xi_f2,zi_f2,dobs_f2 = np.genfromtxt('1123_MagTie.XYZ', skip_header=11, usecols = (0, 1, 7, 15),
#                                              invalid_raise=False, unpack=True)
# Out:
# <ipython-input-15-7d5410f7f0d9>:2: ConversionWarning: Some errors were detected !
#     Line #50976 (got 2 columns instead of 4)
#     Line #94854 (got 2 columns instead of 4)
#     Line #94855 (got 2 columns instead of 4)
#     Line #94856 (got 2 columns instead of 4)
#     Line #142658 (got 2 columns instead of 4)
#     Line #187208 (got 2 columns instead of 4)
#     Line #187209 (got 2 columns instead of 4)
#     Line #187210 (got 2 columns instead of 4)
#     Line #230926 (got 2 columns instead of 4)
#     Line #278981 (got 2 columns instead of 4)
#     Line #278982 (got 2 columns instead of 4)
#     Line #278983 (got 2 columns instead of 4)
#     Line #323104 (got 2 columns instead of 4)
#     Line #371515 (got 2 columns instead of 4)
#     Line #371516 (got 2 columns instead of 4)
#     Line #371517 (got 2 columns instead of 4)
#     Line #415055 (got 2 columns instead of 4)
#     Line #462088 (got 2 columns instead of 4)
#     Line #462089 (got 2 columns instead of 4)
#     Line #462090 (got 2 columns instead of 4)
#     Line #505747 (got 2 columns instead of 4)
#     Line #553577 (got 2 columns instead of 4)
#     Line #553578 (got 2 columns instead of 4)
#     Line #553579 (got 2 columns instead of 4)
#     Line #598803 (got 2 columns instead of 4)
#     Line #645975 (got 2 columns instead of 4)
#     Line #645976 (got 2 columns instead of 4)
#     Line #645977 (got 2 columns instead of 4)
#     Line #692073 (got 2 columns instead of 4)
#     Line #738432 (got 2 columns instead of 4)
#     Line #738433 (got 2 columns instead of 4)
#     Line #738434 (got 2 columns instead of 4)
#     Line #782221 (got 2 columns instead of 4)
#     Line #828177 (got 2 columns instead of 4)
#     Line #828178 (got 2 columns instead of 4)
#     Line #828179 (got 2 columns instead of 4)
#     Line #875007 (got 2 columns instead of 4)
#     Line #875008 (got 2 columns instead of 4)
#     Line #875009 (got 2 columns instead of 4)
#     Line #923241 (got 2 columns instead of 4)
#     Line #923242 (got 2 columns instead of 4)
#     Line #923243 (got 2 columns instead of 4)
#     Line #968085 (got 2 columns instead of 4)
#     Line #968086 (got 2 columns instead of 4)
#     Line #968087 (got 2 columns instead of 4)
#     Line #1013939 (got 2 columns instead of 4)
#     Line #1013940 (got 2 columns instead of 4)
#     Line #1013941 (got 2 columns instead of 4)
#     Line #1060596 (got 2 columns instead of 4)
#     Line #1109830 (got 2 columns instead of 4)
#     Line #1109831 (got 2 columns instead of 4)
#     Line #1109832 (got 2 columns instead of 4)
#     Line #1156162 (got 2 columns instead of 4)
#     Line #1203558 (got 2 columns instead of 4)
#     Line #1203559 (got 2 columns instead of 4)
#     Line #1203560 (got 2 columns instead of 4)
#     Line #1248732 (got 2 columns instead of 4)
#     Line #1248733 (got 2 columns instead of 4)
#     Line #1248734 (got 2 columns instead of 4)
#     Line #1297583 (got 2 columns instead of 4)
#     Line #1297584 (got 2 columns instead of 4)
#     Line #1297585 (got 2 columns instead of 4)
#     Line #1343157 (got 2 columns instead of 4)
#     Line #1343158 (got 2 columns instead of 4)
#     Line #1343159 (got 2 columns instead of 4)
#     Line #1370340 (got 2 columns instead of 4)
#     Line #1370341 (got 2 columns instead of 4)
#     Line #1370342 (got 2 columns instead of 4)
#     Line #1390664 (got 2 columns instead of 4)
#     Line #1390665 (got 2 columns instead of 4)
#     Line #1390666 (got 2 columns instead of 4)
#     Line #1436737 (got 2 columns instead of 4)
#     Line #1436738 (got 2 columns instead of 4)
#     Line #1436739 (got 2 columns instead of 4)
#     Line #1462560 (got 2 columns instead of 4)
#     Line #1485432 (got 2 columns instead of 4)
#     Line #1485433 (got 2 columns instead of 4)
#     Line #1485434 (got 2 columns instead of 4)
#     Line #1530202 (got 2 columns instead of 4)
#     Line #1530203 (got 2 columns instead of 4)
#     Line #1530204 (got 2 columns instead of 4)
#     Line #1554531 (got 2 columns instead of 4)
#     Line #1575942 (got 2 columns instead of 4)
#     Line #1575943 (got 2 columns instead of 4)
#     Line #1575944 (got 2 columns instead of 4)
#     Line #1620966 (got 2 columns instead of 4)
#     Line #1620967 (got 2 columns instead of 4)
#     Line #1620968 (got 2 columns instead of 4)
#     Line #1644951 (got 2 columns instead of 4)
#     Line #1644952 (got 2 columns instead of 4)
#     Line #1644953 (got 2 columns instead of 4)
#     Line #1669000 (got 2 columns instead of 4)
#     Line #1669001 (got 2 columns instead of 4)
#     Line #1669002 (got 2 columns instead of 4)
#     Line #1713756 (got 2 columns instead of 4)
#     Line #1713757 (got 2 columns instead of 4)
#     Line #1713758 (got 2 columns instead of 4)
#     Line #1739984 (got 2 columns instead of 4)
#     Line #1760761 (got 2 columns instead of 4)
#     Line #1760762 (got 2 columns instead of 4)
#     Line #1760763 (got 2 columns instead of 4)
#     Line #1803878 (got 2 columns instead of 4)
#     Line #1803879 (got 2 columns instead of 4)
#     Line #1803880 (got 2 columns instead of 4)
#     Line #1831188 (got 2 columns instead of 4)
#     Line #1831189 (got 2 columns instead of 4)
#     Line #1831190 (got 2 columns instead of 4)
#     Line #1851299 (got 2 columns instead of 4)
#     Line #1851300 (got 2 columns instead of 4)
#     Line #1851301 (got 2 columns instead of 4)
#     Line #1894200 (got 2 columns instead of 4)
#     Line #1894201 (got 2 columns instead of 4)
#     Line #1894202 (got 2 columns instead of 4)
#     Line #1920374 (got 2 columns instead of 4)
#     Line #1940641 (got 2 columns instead of 4)
#     Line #1986093 (got 2 columns instead of 4)
#     Line #1986094 (got 2 columns instead of 4)
#     Line #1986095 (got 2 columns instead of 4)
#     Line #2013857 (got 2 columns instead of 4)
#     Line #2034509 (got 2 columns instead of 4)
#     Line #2077881 (got 2 columns instead of 4)
#     Line #2077882 (got 2 columns instead of 4)
#     Line #2077883 (got 2 columns instead of 4)
#     Line #2104657 (got 2 columns instead of 4)
#     Line #2125509 (got 2 columns instead of 4)
#     Line #2170198 (got 2 columns instead of 4)
#     Line #2170199 (got 2 columns instead of 4)
#     Line #2170200 (got 2 columns instead of 4)
#     Line #2198187 (got 2 columns instead of 4)
#     Line #2219604 (got 2 columns instead of 4)
#     Line #2264106 (got 2 columns instead of 4)
#     Line #2264107 (got 2 columns instead of 4)
#     Line #2264108 (got 2 columns instead of 4)
#     Line #2311729 (got 2 columns instead of 4)
#     Line #2357147 (got 2 columns instead of 4)
#     Line #2357148 (got 2 columns instead of 4)
#     Line #2357149 (got 2 columns instead of 4)
#     Line #2404526 (got 2 columns instead of 4)
#     Line #2450444 (got 2 columns instead of 4)
#     Line #2450445 (got 2 columns instead of 4)
#     Line #2450446 (got 2 columns instead of 4)
#     Line #2460077 (got 2 columns instead of 4)
#     Line #2460078 (got 2 columns instead of 4)
#     Line #2460079 (got 2 columns instead of 4)
#     Line #2499861 (got 2 columns instead of 4)
#     Line #2499862 (got 2 columns instead of 4)
#     Line #2499863 (got 2 columns instead of 4)
#     Line #2545139 (got 2 columns instead of 4)
#     Line #2545140 (got 2 columns instead of 4)
#     Line #2545141 (got 2 columns instead of 4)
#     Line #2559113 (got 2 columns instead of 4)
#     Line #2559114 (got 2 columns instead of 4)
#     Line #2559115 (got 2 columns instead of 4)
#     Line #2590704 (got 2 columns instead of 4)
#     Line #2590705 (got 2 columns instead of 4)
#     Line #2590706 (got 2 columns instead of 4)
#     Line #2637015 (got 2 columns instead of 4)
#     Line #2637016 (got 2 columns instead of 4)
#     Line #2637017 (got 2 columns instead of 4)
#     Line #2683761 (got 2 columns instead of 4)
#     Line #2683762 (got 2 columns instead of 4)
#     Line #2683763 (got 2 columns instead of 4)
#     Line #2730697 (got 2 columns instead of 4)
#     Line #2777763 (got 2 columns instead of 4)
#     Line #2777764 (got 2 columns instead of 4)
#     Line #2777765 (got 2 columns instead of 4)
#     Line #2824177 (got 2 columns instead of 4)
#     Line #2870591 (got 2 columns instead of 4)
#     Line #2870592 (got 2 columns instead of 4)
#     Line #2870593 (got 2 columns instead of 4)
#     Line #2918306 (got 2 columns instead of 4)
#     Line #2918307 (got 2 columns instead of 4)
#     Line #2918308 (got 2 columns instead of 4)
#     Line #2964964 (got 2 columns instead of 4)
#     Line #2964965 (got 2 columns instead of 4)
#     Line #2964966 (got 2 columns instead of 4)
#     Line #3012656 (got 2 columns instead of 4)
#     Line #3012657 (got 2 columns instead of 4)
#     Line #3012658 (got 2 columns instead of 4)
#     Line #3059220 (got 2 columns instead of 4)
#     Line #3105898 (got 2 columns instead of 4)
#     Line #3105899 (got 2 columns instead of 4)
#     Line #3105900 (got 2 columns instead of 4)
#     Line #3152922 (got 2 columns instead of 4)
#     Line #3152923 (got 2 columns instead of 4)
#     Line #3152924 (got 2 columns instead of 4)
#     Line #3199692 (got 2 columns instead of 4)
#     Line #3199693 (got 2 columns instead of 4)
#     Line #3246455 (got 2 columns instead of 4)
#     Line #3246456 (got 2 columns instead of 4)
#     Line #3246457 (got 2 columns instead of 4)
#     Line #3293107 (got 2 columns instead of 4)
#     Line #3293108 (got 2 columns instead of 4)
#     Line #3339794 (got 2 columns instead of 4)
#     Line #3339795 (got 2 columns instead of 4)
#     Line #3386239 (got 2 columns instead of 4)
#     Line #3386240 (got 2 columns instead of 4)
#     Line #3432830 (got 2 columns instead of 4)
#     Line #3432831 (got 2 columns instead of 4)
#     Line #3432832 (got 2 columns instead of 4)
#     Line #3479312 (got 2 columns instead of 4)
#     Line #3479313 (got 2 columns instead of 4)
#     Line #3525757 (got 2 columns instead of 4)
#     Line #3525758 (got 2 columns instead of 4)
#     Line #3525759 (got 2 columns instead of 4)
#     Line #3571031 (got 2 columns instead of 4)
#     Line #3571032 (got 2 columns instead of 4)
#     Line #3616634 (got 2 columns instead of 4)
#     Line #3616635 (got 2 columns instead of 4)
#     Line #3661941 (got 2 columns instead of 4)
#     Line #3707965 (got 2 columns instead of 4)
#     Line #3707966 (got 2 columns instead of 4)
#     Line #3707967 (got 2 columns instead of 4)
#     Line #3753435 (got 2 columns instead of 4)
#     Line #3799227 (got 2 columns instead of 4)
#     Line #3799228 (got 2 columns instead of 4)
#     Line #3799229 (got 2 columns instead of 4)
#     Line #3844293 (got 2 columns instead of 4)
#     Line #3889993 (got 2 columns instead of 4)
#     Line #3889994 (got 2 columns instead of 4)
#     Line #3889995 (got 2 columns instead of 4)
#     Line #3936715 (got 2 columns instead of 4)
#     Line #3982917 (got 2 columns instead of 4)
#     Line #3982918 (got 2 columns instead of 4)
#     Line #3982919 (got 2 columns instead of 4)
#     Line #4030206 (got 2 columns instead of 4)
#     Line #4030207 (got 2 columns instead of 4)
#     Line #4030208 (got 2 columns instead of 4)
#     Line #4076462 (got 2 columns instead of 4)
#     Line #4076463 (got 2 columns instead of 4)
#     Line #4076464 (got 2 columns instead of 4)
#     Line #4123692 (got 2 columns instead of 4)
#     Line #4169968 (got 2 columns instead of 4)
#     Line #4169969 (got 2 columns instead of 4)
#     Line #4169970 (got 2 columns instead of 4)
#     Line #4216488 (got 2 columns instead of 4)
#     Line #4216489 (got 2 columns instead of 4)
#     Line #4262771 (got 2 columns instead of 4)
#     Line #4262772 (got 2 columns instead of 4)
#     Line #4262773 (got 2 columns instead of 4)
#     Line #4309003 (got 2 columns instead of 4)
#     Line #4355507 (got 2 columns instead of 4)
#     Line #4355508 (got 2 columns instead of 4)
#     Line #4355509 (got 2 columns instead of 4)
#     Line #4401363 (got 2 columns instead of 4)
#     Line #4401364 (got 2 columns instead of 4)
#     Line #4448062 (got 2 columns instead of 4)
#     Line #4448063 (got 2 columns instead of 4)
#     Line #4448064 (got 2 columns instead of 4)
#     Line #4494750 (got 2 columns instead of 4)
#     Line #4494751 (got 2 columns instead of 4)
#     Line #4510750 (got 2 columns instead of 4)
#     Line #4510751 (got 2 columns instead of 4)
#     Line #4510752 (got 2 columns instead of 4)
#     Line #4542166 (got 2 columns instead of 4)
#     Line #4542167 (got 2 columns instead of 4)
#     Line #4542168 (got 2 columns instead of 4)
#     Line #4589112 (got 2 columns instead of 4)
#     Line #4636644 (got 2 columns instead of 4)
#     Line #4636645 (got 2 columns instead of 4)
#     Line #4636646 (got 2 columns instead of 4)
#     Line #4681878 (got 2 columns instead of 4)
#     Line #4681879 (got 2 columns instead of 4)
#     Line #4681880 (got 2 columns instead of 4)
#     Line #4728314 (got 2 columns instead of 4)
#     Line #4728315 (got 2 columns instead of 4)
#     Line #4773675 (got 2 columns instead of 4)
#     Line #4773676 (got 2 columns instead of 4)
#     Line #4773677 (got 2 columns instead of 4)
#     Line #4819309 (got 2 columns instead of 4)
#     Line #4866025 (got 2 columns instead of 4)
#     Line #4866026 (got 2 columns instead of 4)
#     Line #4866027 (got 2 columns instead of 4)
#     Line #4911881 (got 2 columns instead of 4)
#     Line #4958021 (got 2 columns instead of 4)
#     Line #4958022 (got 2 columns instead of 4)
#     Line #4958023 (got 2 columns instead of 4)
#     Line #5003693 (got 2 columns instead of 4)
#     Line #5049447 (got 2 columns instead of 4)
#     Line #5049448 (got 2 columns instead of 4)
#     Line #5049449 (got 2 columns instead of 4)
#     Line #5096617 (got 2 columns instead of 4)
#     Line #5142877 (got 2 columns instead of 4)
#     Line #5142878 (got 2 columns instead of 4)
#     Line #5142879 (got 2 columns instead of 4)
#     Line #5168013 (got 2 columns instead of 4)
#     Line #5168014 (got 2 columns instead of 4)
#     Line #5168015 (got 2 columns instead of 4)
#     Line #5189405 (got 2 columns instead of 4)
#     Line #5189406 (got 2 columns instead of 4)
#     Line #5189407 (got 2 columns instead of 4)
#     Line #5214537 (got 2 columns instead of 4)
#     Line #5214538 (got 2 columns instead of 4)
#     Line #5214539 (got 2 columns instead of 4)
#     Line #5235263 (got 2 columns instead of 4)
#     Line #5235264 (got 2 columns instead of 4)
#     Line #5235265 (got 2 columns instead of 4)
#     Line #5255183 (got 2 columns instead of 4)
#     Line #5255184 (got 2 columns instead of 4)
#     Line #5255185 (got 2 columns instead of 4)
#     Line #5281475 (got 2 columns instead of 4)
#     Line #5281476 (got 2 columns instead of 4)
#     Line #5281477 (got 2 columns instead of 4)
#     Line #5301951 (got 2 columns instead of 4)
#     Line #5301952 (got 2 columns instead of 4)
#     Line #5301953 (got 2 columns instead of 4)
#     Line #5327735 (got 2 columns instead of 4)
#     Line #5327736 (got 2 columns instead of 4)
#     Line #5327737 (got 2 columns instead of 4)
#     Line #5374848 (got 2 columns instead of 4)
#     Line #5422254 (got 2 columns instead of 4)
#     Line #5422255 (got 2 columns instead of 4)
#     Line #5422256 (got 2 columns instead of 4)
#     Line #5469796 (got 2 columns instead of 4)
#     Line #5517926 (got 2 columns instead of 4)
#     Line #5517927 (got 2 columns instead of 4)
#     Line #5564695 (got 2 columns instead of 4)
#     Line #5564696 (got 2 columns instead of 4)
#     Line #5611594 (got 2 columns instead of 4)
#     Line #5611595 (got 2 columns instead of 4)
#     Line #5658019 (got 2 columns instead of 4)
#     Line #5658020 (got 2 columns instead of 4)
#     Line #5705811 (got 2 columns instead of 4)
#     Line #5705812 (got 2 columns instead of 4)
#     Line #5753274 (got 2 columns instead of 4)
#     Line #5753275 (got 2 columns instead of 4)
#     Line #5799957 (got 2 columns instead of 4)
#     Line #5799958 (got 2 columns instead of 4)
#     Line #5846314 (got 2 columns instead of 4)
#     Line #5846315 (got 2 columns instead of 4)
#     Line #5892647 (got 2 columns instead of 4)
#     Line #5892648 (got 2 columns instead of 4)
#     Line #5939222 (got 2 columns instead of 4)
#     Line #5939223 (got 2 columns instead of 4)
#     Line #5986339 (got 2 columns instead of 4)
#     Line #5986340 (got 2 columns instead of 4)
#     Line #6034358 (got 2 columns instead of 4)
#   yi_c,xi_c,zi_c,dobs_c = np.genfromtxt('1123_MagLine.XYZ', skip_header=11, usecols = (0, 1, 7, 15),

# %%
#xi_c = np.hstack((xi_f1,xi_f2))
#yi_c = np.hstack((yi_f1,yi_f2))
#zi_c = np.hstack((zi_f1,zi_f2))
#dobs_c = np.hstack((dobs_f1,dobs_f2))

# %% [markdown]
# # Create a regular grid using the observation data

# %%
# Create a regular grid
shape_m = (10000, 131)
grid_x = np.linspace(np.min(xi_c),np.max(xi_c),shape_m[0])
grid_y = np.linspace(np.min(yi_c),np.max(yi_c),shape_m[1])
grid_y, grid_x = np.meshgrid(grid_y, grid_x)
grid_z = np.zeros_like(grid_x)-900
grid_dobs = griddata((xi_c,yi_c), dobs_c, (grid_x, grid_y), method='nearest')

# %%
grid_dobs.shape
# Out:
# (10000, 131)

# %%
carajas = dict()
carajas['x'] = np.ravel(grid_x)
carajas['y'] = np.ravel(grid_y)
carajas['z'] = np.ravel(grid_z)
carajas['tf'] = np.ravel(grid_dobs)

# %%
#save the data
file_name = 'carajas_grid_line_tf.pickle'
with open(file_name, 'wb') as f:
    pickle.dump(carajas, f)

# %% [markdown]
# # Test pickle file

# %%
with open('carajas_grid_line_tf.pickle', 'rb') as r:
    carajas_test = pickle.load(r)

# %%
carajas_test['x']
# Out:
# array([9097246.36, 9097246.36, 9097246.36, ..., 9462854.96, 9462854.96,
#        9462854.96])

# %%
carajas_test['y']
# Out:
# array([277429.38      , 280430.05392308, 283430.72784615, ...,
#        661515.64215385, 664516.31607692, 667516.99      ])
